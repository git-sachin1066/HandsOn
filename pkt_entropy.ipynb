# %%
import numpy as np
import cv2

# %%
class ImageEntropy:
    def __init__(self, file):
        self.greyIm = file

    def entropy(self, signal):
        '''
        function returns entropy of a signal
        signal must be a 1-D numpy array
        '''
        lensig = signal.size
        symset = list(set(signal))
        numsym = len(symset)
        propab = [np.size(signal[signal == i]) / (1.0 * lensig) for i in symset]
        ent = np.sum([p * np.log2(1.0 / p) for p in propab])
        return ent

    def img_entro(self):
        greyImg = np.array(self.greyIm)
        region = greyImg.flatten()
        result = self.entropy(region)
        return result

# %%
def remove_line(img):
    result = img.copy()
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    thresh_img = cv2.adaptiveThreshold(gray,
                                       255,
                                       cv2.ADAPTIVE_THRESH_MEAN_C,
                                       cv2.THRESH_BINARY_INV,
                                       25,
                                       15)
    # Remove horizontal lines
    horizontal_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (80, 1))
    remove_horizontal = cv2.morphologyEx(thresh_img,
                                         cv2.MORPH_OPEN,
                                         horizontal_kernel,
                                         iterations=1)
    cnts = cv2.findContours(remove_horizontal,
                            cv2.RETR_EXTERNAL,
                            cv2.CHAIN_APPROX_SIMPLE)
    cnts = cnts[0] if len(cnts) == 2 else cnts[1]
    for c in cnts:
        cv2.drawContours(result, [c], -1, (255, 255, 255), 7)
    # Remove vertical lines
    vertical_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (1, 80))
    remove_vertical = cv2.morphologyEx(thresh_img,
                                       cv2.MORPH_OPEN,
                                       vertical_kernel,
                                       iterations=1)
    cnts = cv2.findContours(remove_vertical,
                            cv2.RETR_EXTERNAL,
                            cv2.CHAIN_APPROX_SIMPLE)
    cnts = cnts[0] if len(cnts) == 2 else cnts[1]
    for c in cnts:
        cv2.drawContours(result, [c], 0, (255, 255, 255), 7)

    repair_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (1, 1))
    result_2 = 255 - cv2.morphologyEx(255 - result,
                                      cv2.MORPH_CLOSE,
                                      repair_kernel,
                                      iterations=1)

    return result_2

# %%
def remove_text(img):
    result = img - remove_line(img)
    final_result = 255 - result

    return final_result

# %%
import os

directory = r'C:\Users\admin'
for filename in os.listdir(directory):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        print(os.path.join(directory, filename))
    else:
        continue



def ocr_preprocessing(path, output, language_list):
    input_image = Image.open(path)
    ###
    print('load image ' + str(path))
    head, tail = os.path.split(path)
    img = cv2.imread(path)

    entro = ImageEntropy(remove_text(img)).img_entro()
    if entro > 0.2:
        img = remove_line(img)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-aa9dfe10faa3> in <module>
#       2
#       3 directory = r'C:\Users\admin'
# ----> 4 for filename in os.listdir(directory):
#       5     if filename.endswith(".jpg") or filename.endswith(".png"):
#       6         print(os.path.join(directory, filename))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\admin'

# %%
import os
pathimage=[]
directory = r"C:\pkt\all_png"

for filename in os.listdir(directory):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        pathimage.append(os.path.join(directory, filename))
    else:
        continue

# %%
import os 
pathzaghart=[]
directory='/Users/farah/Desktop'
print(os.path)
# for name in os.listdir(directory):
#     if name.endswith('.pdf'):
#         pathzaghart.append(os.path.join(directory,filename))
# Out:
# <module 'ntpath' from 'c:\\users\\sachinverma\\appdata\\local\\programs\\python\\python37\\lib\\ntpath.py'>

# %%
pathimage
# Out:
# ['C:\\pkt\\all_png\\10pdf_1.png',
#  'C:\\pkt\\all_png\\10pdf_2.png',
#  'C:\\pkt\\all_png\\10pdf_3.png',
#  'C:\\pkt\\all_png\\10pdf_4.png',
#  'C:\\pkt\\all_png\\10pdf_5.png',
#  'C:\\pkt\\all_png\\1pdf_1.png',
#  'C:\\pkt\\all_png\\1pdf_19.png',
#  'C:\\pkt\\all_png\\1pdf_2.png',
#  'C:\\pkt\\all_png\\1pdf_20.png',
#  'C:\\pkt\\all_png\\1pdf_21.png',
#  'C:\\pkt\\all_png\\1pdf_22.png',
#  'C:\\pkt\\all_png\\1pdf_23.png',
#  'C:\\pkt\\all_png\\1pdf_3.png',
#  'C:\\pkt\\all_png\\1pdf_30.png',
#  'C:\\pkt\\all_png\\1pdf_31.png',
#  'C:\\pkt\\all_png\\1pdf_4.png',
#  'C:\\pkt\\all_png\\1pdf_5.png',
#  'C:\\pkt\\all_png\\2pdf_16.png',
#  'C:\\pkt\\all_png\\2pdf_17.png',
#  'C:\\pkt\\all_png\\2pdf_18.png',
#  'C:\\pkt\\all_png\\2pdf_27.png',
#  'C:\\pkt\\all_png\\2pdf_28.png',
#  'C:\\pkt\\all_png\\2pdf_29.png',
#  'C:\\pkt\\all_png\\2pdf_30.png',
#  'C:\\pkt\\all_png\\2pdf_31.png',
#  'C:\\pkt\\all_png\\2pdf_32.png',
#  'C:\\pkt\\all_png\\3pdf_1.png',
# ...

# %%
import os 
for path in pathimage:
    try:
        print('image path : '+str(path))
        img = cv2.imread(path)
        head, tail = os.path.split(path)

        entro = ImageEntropy(remove_text(img)).img_entro()
        if entro > 0.2:
            img = remove_line(img)
            tail = 'lineremove' + tail
        else:
            tail = 'notremove' + tail

        cv2.imwrite(os.path.join(r'C:\pkt\cross_entropy_pkt',tail),img)
    except : 
        print('')
# Out:
# image path : C:\pkt\all_png\10pdf_1.png
# image path : C:\pkt\all_png\10pdf_2.png
# image path : C:\pkt\all_png\10pdf_3.png
# image path : C:\pkt\all_png\10pdf_4.png
# image path : C:\pkt\all_png\10pdf_5.png
# image path : C:\pkt\all_png\1pdf_1.png
# image path : C:\pkt\all_png\1pdf_19.png
# image path : C:\pkt\all_png\1pdf_2.png
# image path : C:\pkt\all_png\1pdf_20.png
# image path : C:\pkt\all_png\1pdf_21.png
# image path : C:\pkt\all_png\1pdf_22.png
# image path : C:\pkt\all_png\1pdf_23.png
# image path : C:\pkt\all_png\1pdf_3.png
# image path : C:\pkt\all_png\1pdf_30.png
# image path : C:\pkt\all_png\1pdf_31.png
# image path : C:\pkt\all_png\1pdf_4.png
# image path : C:\pkt\all_png\1pdf_5.png
# image path : C:\pkt\all_png\2pdf_16.png
# image path : C:\pkt\all_png\2pdf_17.png
# image path : C:\pkt\all_png\2pdf_18.png
# image path : C:\pkt\all_png\2pdf_27.png
# image path : C:\pkt\all_png\2pdf_28.png
# image path : C:\pkt\all_png\2pdf_29.png
# ...

# %%
type(a)
# Out:
# numpy.ndarray

# %%
from pdf2image.exceptions import (
    PDFInfoNotInstalledError,
    PDFPageCountError,
    PDFSyntaxError
)

# %%
images = convert_from_path('/home/belval/example.pdf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-98-aa77824c8cfe> in <module>
# ----> 1 images = convert_from_path('/home/belval/example.pdf')
#
# NameError: name 'convert_from_path' is not defined

# %%
import os
pathimage=[]
directory = "/Users/farah/Desktop/task/Ai"
for filename in os.listdir(directory):
    if filename.endswith(".pdf") :
        filename = convert_from_path('/home/belval/example.pdf')
        pathimage.append(os.path.join(directory, filename))
    else:
        continue
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-99-c9ef1741aed0> in <module>
#       4 for filename in os.listdir(directory):
#       5     if filename.endswith(".pdf") :
# ----> 6         filename = convert_from_path('/home/belval/example.pdf')
#       7         pathimage.append(os.path.join(directory, filename))
#       8     else:
#
# NameError: name 'convert_from_path' is not defined

# %%
images = convert_from_bytes(open('/home/belval/example.pdf', 'rb').read())

# %%
for path in pathimage:
    img = cv2.imread(path)
    head, tail = os.path.split(path)
    cv2.imwrite('/Users/farah/Desktop/task/Ai_img/'+tail,img)

# %%
import re
from pdf2image import convert_from_path
def convertPDFToPNG(path, pdf_destination):
    full_img_path = []

    # loop over all files in path
    c = 0

    pdf_name = re.sub("\.+", "", (os.path.split(path)[1]))
    print(pdf_name)
    pages = convert_from_path(path)  
    print('numbr images' + str(len(pages)))# get all pages in each pdf file
    if len(pages) > 2:
    # loop over all pages in pages
        for i in range(0, 3):
            c += 1
            saveName_pdf = (pdf_destination + os.path.sep + pdf_name + ('_') + str(i + 1) + '.png')
            print(i)
            pages[i].save(saveName_pdf, 'png')
            full_img_path.append(saveName_pdf)
        print('this many full images we have' + str(len(full_img_path)))
    else :
        for i in range(0, len(pages)):
            c += 1
            saveName_pdf = (pdf_destination + os.path.sep + pdf_name + ('_') + str(i + 1) + '.png')
            print(i)
            pages[i].save(saveName_pdf, 'png')
            full_img_path.append(saveName_pdf)
        print('this many full images we have' + str(len(full_img_path)))
    return 0, full_img_path

# %%
import os
pathpdf=[]
directory = '/Users/farah/Desktop/pkt/PKT/Task/File_path/'
for filename in os.listdir(directory):
    if filename.endswith(".pdf") :
        directory+filename
        pathpdf.append(os.path.join(directory, filename))
    else:
        continue

# %%
os.path.sep
# Out:
# '/'

# %%
output = '/Users/farah/Desktop/pkt/PKT/Task/new_final'
for file_path in pathpdf : 
    _, paths =convertPDFToPNG(file_path, output)
# Out:
# E PBIM19120477 YZPKG5572019 E193243159650340Pdfpdf
# numbr images11
# 0
# 1
# 2
# this many full images we have3
# FIN_NSPKG5412019_20190807182838pdf
# numbr images5
# 0
# 1
# 2
# this many full images we have3
# FIN_PKG5592019SH_20190820183429pdfpdf
# numbr images3
# 0
# 1
# 2
# this many full images we have3
# D PBIM19080206 WTH7-PKG-506-2019 D2019-0217486pdf
# numbr images17
# 0
# 1
# 2
# this many full images we have3
# E PBIM19080249 NSPKG5412019_5 E194434WLD010320pdf
# numbr images4
# 0
# 1
# 2
# this many full images we have3
# E PBIM20010033 TAPKG5362019-1 E197837462700043Pdfpdf
# numbr images6
# 0
# 1
# 2
# this many full images we have3
# D PBIM19090584 WMAL-6292019-A-1 VN-MY 190505731pdf
# numbr images2
# 0
# 1
# this many full images we have2
# E PBIM19090204 PKG5692019SH-3 E193105700150744Pdfpdf
# numbr images6
# 0
# 1
# 2
# this many full images we have3
# 9pdf
# numbr images92
# 0
# 1
# 2
# this many full images we have3
# IMPORT - VINDA1pdf
# numbr images6
# 0
# 1
# ...
